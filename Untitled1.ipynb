# %%
from rdkit.Chem import PandasTools
import pandas as pd
import numpy as np
pd.options.display.max_columns = 30

# %%
df_sdf_FDA = PandasTools.LoadSDF("lifechem_0.sdf")
# Out:
# [17:13:02] Warning: molecule is tagged as 3D, but all Z coords are zero
# [17:13:02] Warning: molecule is tagged as 3D, but all Z coords are zero
# [17:13:02] Warning: molecule is tagged as 3D, but all Z coords are zero
# [17:13:02] Warning: molecule is tagged as 3D, but all Z coords are zero
# [17:13:02] Warning: molecule is tagged as 3D, but all Z coords are zero
# [17:13:02] Warning: molecule is tagged as 3D, but all Z coords are zero
# [17:13:02] Warning: molecule is tagged as 3D, but all Z coords are zero
# [17:13:02] Warning: molecule is tagged as 3D, but all Z coords are zero
# [17:13:02] Warning: molecule is tagged as 3D, but all Z coords are zero
# [17:13:02] Warning: molecule is tagged as 3D, but all Z coords are zero
# [17:13:02] Warning: molecule is tagged as 3D, but all Z coords are zero
# [17:13:02] Warning: molecule is tagged as 3D, but all Z coords are zero
# [17:13:02] Warning: molecule is tagged as 3D, but all Z coords are zero
# ...

# %%
df_sdf_FDA
# Out:
#       Custom_Parent_ID   Vendor_CN      MWONE     MWBASE Amount  \
# 0          STR-0018800  F0001-2180  219.31036  219.31036  2umol
# 1          STR-0018801  F0001-2377   161.2025   161.2025  2umol
# 2          STR-0018802  F0010-0304  394.92377  394.92377  2umol
# 3          STR-0018803  F0012-0104  226.30205  226.30205  2umol
# 4          STR-0018804  F0013-0543  365.45407  365.45407  2umol
# ...                ...         ...        ...        ...    ...
# 9996       STR-0028796  F0526-1863  532.53656  496.07556  2umol
# 9997       STR-0028797  F0526-1865  557.11615  520.65515  2umol
# 9998       STR-0028798  F0526-1867  543.08905  506.62805  2umol
# 9999       STR-0028799  F0526-1873  516.15045  479.68951  2umol
# 10000      STR-0028800  F0526-1875  502.12338  465.66241  2umol
#
#       Original_Plate Row Col ID Salt_Status salt New_Col Original_Well  \
# 0          PLATE5001   A  02            nan  nan       2            A2
# ...
